# %% [raw]
# ---
# output-file: index.html
# title: Malware Detection from Network Captures using Machine Learning
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install mdetect
# ```

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Feature Engineering
#
# ## Model Selection
#
# ## ML Ops Pipeline
# Design a pipeline for your model in Elastic. The pipeline should include the technologies that you will use, whether this is Elastic or others, for the following:
# - Feature registry,
# - Model registry,
# - Model Deployment, - Testing.
#
# ## Conclusions
#
# ## References
