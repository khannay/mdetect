# %% [raw]
# ---
# description: Define some wrappers for command line tools for training the models
# output-file: cli.html
# title: Command Line tools
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(main_train)
# Out:
# ---
#
# [source](https://github.com/khannay/mdetect/blob/main/mdetect/cli.py#L32){target="_blank" style="float:right; font-size:smaller"}
#
# ### main_train
#
# >      main_train ()

# %%
#| echo: false
#| output: asis
show_doc(main_transform)
# Out:
# ---
#
# [source](https://github.com/khannay/mdetect/blob/main/mdetect/cli.py#L86){target="_blank" style="float:right; font-size:smaller"}
#
# ### main_transform
#
# >      main_transform ()

# %%
#| echo: false
#| output: asis
show_doc(main_predict)
# Out:
# ---
#
# [source](https://github.com/khannay/mdetect/blob/main/mdetect/cli.py#L99){target="_blank" style="float:right; font-size:smaller"}
#
# ### main_predict
#
# >      main_predict ()
